# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', size=18); plt.rcParams['figure.constrained_layout.use'] = True
import datetime

# %%
df1 = pd.read_csv('data/buckingham.csv', usecols=[1,5])
df2 = pd.read_csv('data/kilmainham.csv', usecols=[1,5])

df = df1

start = pd.to_datetime(str(min(df.TIME)))   # 2020-01-01 06:25:02. Data only reliable after 2020-01-26.
end = pd.to_datetime(str(max(df.TIME)))     # 2020-04-01 23:55:02. 
start_date = start.date()
end_date = end.date()

t_start = pd.DatetimeIndex([start]).astype(np.int64)/1000000000
t_end = pd.DatetimeIndex([end]).astype(np.int64)/1000000000

# %%
df1 = pd.read_csv('data/buckingham.csv', usecols=[1,5])
df2 = pd.read_csv('data/kilmainham.csv', usecols=[1,5])

df = df1

start = pd.to_datetime("26-01-2020",format='%d-%m-%Y')   # Sunday
end = pd.to_datetime("26-01-2020",format='%d-%m-%Y')   # 2020-04-01 23:55:02. 
start_date = start.date()
end_date = end.date()

t_start = pd.DatetimeIndex([start]).astype(np.int64)/1000000000
t_end = pd.DatetimeIndex([end]).astype(np.int64)/1000000000

# %% [markdown]
# need to decide training data size/dates

# %%
t_full=pd.array(pd.DatetimeIndex(df.iloc[:,0]).astype(np.int64))/1000000000
dt = t_full[1] - t_full[0]
print(f"sampling interval = {dt} seconds")
# Out:
# sampling interval = 300.0 seconds

# %%
# t = np.extract([(t_full>=t_start) & (t_full<=t_end)], t_full)

# %%
plt.scatter(t_full, df['AVAILABLE BIKES'])

# %% [markdown]
# looks like there's a period of missing data up until sunday jan 26th (1580000000)
