# %% [markdown]
# ## Predicting bike availability

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/dublinbikes_20200101_20200401.csv')
# bike_station_1_df = df.
addresses = df.ADDRESS.unique()
# print(addresses)

# %%
df1 = df[df.ADDRESS == addresses[0]]
df1
lats = df.LATITUDE.unique()
longs = df.LONGITUDE.unique()
latlongs = np.column_stack((lats,longs))
IDs = df['STATION ID'].unique()
# IDs
# latlongs

# %%
# print(min(lats))    # 53.3301
# print(max(lats))    # 53.36
# print(min(longs))   # -6.3101
# print(max(longs))   # -6.2309

# %%
df1
# Out:
#          STATION ID                 TIME         LAST UPDATED  \
# 0                 2  2020-01-01 06:25:02  2020-01-01 06:24:06
# 1                 2  2020-01-01 06:30:02  2020-01-01 06:24:06
# 2                 2  2020-01-01 06:35:02  2020-01-01 06:34:15
# 3                 2  2020-01-01 06:40:03  2020-01-01 06:37:22
# 4                 2  2020-01-01 06:45:02  2020-01-01 06:37:22
# ...             ...                  ...                  ...
# 2196881           2  2020-04-01 23:35:02  2020-04-01 23:31:57
# 2196882           2  2020-04-01 23:40:02  2020-04-01 23:31:57
# 2196883           2  2020-04-01 23:45:02  2020-04-01 23:42:06
# 2196884           2  2020-04-01 23:50:03  2020-04-01 23:42:06
# 2196885           2  2020-04-01 23:55:02  2020-04-01 23:52:15
#
#                        NAME  BIKE STANDS  AVAILABLE BIKE STANDS  \
# 0        BLESSINGTON STREET           20                     18
# 1        BLESSINGTON STREET           20                     18
# 2        BLESSINGTON STREET           20                     18
# 3        BLESSINGTON STREET           20                     20
# 4        BLESSINGTON STREET           20                     20
# ...                     ...          ...                    ...
# 2196881  BLESSINGTON STREET           20                     12
# 2196882  BLESSINGTON STREET           20                     12
# 2196883  BLESSINGTON STREET           20                     12
# 2196884  BLESSINGTON STREET           20                     12
# 2196885  BLESSINGTON STREET           20                     12
#
#          AVAILABLE BIKES STATUS             ADDRESS  LATITUDE  LONGITUDE
# 0                      2   Open  Blessington Street  53.35677   -6.26814
# 1                      2   Open  Blessington Street  53.35677   -6.26814
# 2                      2   Open  Blessington Street  53.35677   -6.26814
# 3                      0   Open  Blessington Street  53.35677   -6.26814
# 4                      0   Open  Blessington Street  53.35677   -6.26814
# ...                  ...    ...                 ...       ...        ...
# 2196881                8   Open  Blessington Street  53.35677   -6.26814
# 2196882                8   Open  Blessington Street  53.35677   -6.26814
# 2196883                8   Open  Blessington Street  53.35677   -6.26814
# 2196884                8   Open  Blessington Street  53.35677   -6.26814
# 2196885                8   Open  Blessington Street  53.35677   -6.26814
#
# [20370 rows x 11 columns]

# %%
time =  df1['TIME'].tolist()
time = range(0,len(time))
bikes = df1['AVAILABLE BIKES'].tolist()

# %% [markdown]
# ## Plot of stations on map

# %%
# map = plt.figure()
# map = plt.imshow('map.png')

im = plt.imread('map.png')
# map = plt.imshow(im, extent= [53.3301, 53.36, -6.3101, -6.2309])
plt.figure('map',figsize=(16,20))
# map = plt.imshow(im, extent= [ -6.3101, -6.2309,53.3301, 53.36])
plt.imshow(im, extent= [ -6.3101, -6.2309,53.3301, 53.36])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Map of Dublin City Centre')
for i in range(len(longs)):
    plt.scatter(longs[i], lats[i])
    plt.annotate(f'{IDs[i]}',xy=(longs[i],lats[i]))
plt.rc('font', size=14)

# %%
# plot df1
# time =  df1['TIME'].tolist()
plt.figure(figsize=(14,10))
plt.scatter(time, bikes)
plt.xlabel('Reading No')
plt.ylabel('No. Available Bikes')
plt.title('')
# Out:
# Text(0.5, 1.0, '')
