# %% [markdown]
# ## Predicting bike availability

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/dublinbikes_20200101_20200401.csv')
# bike_station_1_df = df.
addresses = df.ADDRESS.unique()
# print(addresses)

# %%
df1 = df[df.ADDRESS == addresses[5]]
df1
# Out:
#          STATION ID                 TIME         LAST UPDATED         NAME  \
# 839               7  2020-01-01 06:25:02  2020-01-01 06:22:09  HIGH STREET
# 840               7  2020-01-01 06:30:02  2020-01-01 06:22:09  HIGH STREET
# 841               7  2020-01-01 06:35:02  2020-01-01 06:32:18  HIGH STREET
# 842               7  2020-01-01 06:40:03  2020-01-01 06:32:18  HIGH STREET
# 843               7  2020-01-01 06:45:02  2020-01-01 06:42:27  HIGH STREET
# ...             ...                  ...                  ...          ...
# 2198321           7  2020-04-01 23:35:02  2020-04-01 23:32:17  HIGH STREET
# 2198322           7  2020-04-01 23:40:02  2020-04-01 23:32:17  HIGH STREET
# 2198323           7  2020-04-01 23:45:02  2020-04-01 23:42:25  HIGH STREET
# 2198324           7  2020-04-01 23:50:03  2020-04-01 23:42:25  HIGH STREET
# 2198325           7  2020-04-01 23:55:02  2020-04-01 23:52:33  HIGH STREET
#
#          BIKE STANDS  AVAILABLE BIKE STANDS  AVAILABLE BIKES STATUS  \
# 839               29                     14               15   Open
# 840               29                     14               15   Open
# 841               29                     14               15   Open
# 842               29                     14               15   Open
# 843               29                     14               15   Open
# ...              ...                    ...              ...    ...
# 2198321           29                     19               10   Open
# 2198322           29                     19               10   Open
# 2198323           29                     19               10   Open
# 2198324           29                     19               10   Open
# 2198325           29                     19               10   Open
#
#              ADDRESS   LATITUDE  LONGITUDE
# 839      High Street  53.343567  -6.275071
# 840      High Street  53.343567  -6.275071
# 841      High Street  53.343567  -6.275071
# 842      High Street  53.343567  -6.275071
# 843      High Street  53.343567  -6.275071
# ...              ...        ...        ...
# 2198321  High Street  53.343567  -6.275071
# 2198322  High Street  53.343567  -6.275071
# 2198323  High Street  53.343567  -6.275071
# 2198324  High Street  53.343567  -6.275071
# 2198325  High Street  53.343567  -6.275071
#
# [20375 rows x 11 columns]
